# %% [markdown]
# # Análisis Comparativo de Emisiones de CO2 en Países del Mundo

# %% [markdown]
# ## Importar Librerías y Carga de Datos
# A continuación importaremos las librerías necesarias para realizar nuestro ejercicio. Posteriormente cargaremos la base de datos usando pandas.

# %%
# !pip install skimpy
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#Tratar Datos
import numpy as np
import pandas as pd
from skimpy import clean_columns

#Visualización
import matplotlib.pyplot as plt 
import seaborn as sns 

#Leer datos
df=pd.read_csv(r"C:\Users\User\Downloads\CO2 emission by countries.csv~1\CO2 emission by countries.csv",encoding="latin1")
#Mostrar Datos
display(df)
# Out:
#            Country Code Calling Code  Year  CO2 emission (Tons)  \
# 0      Afghanistan   AF           93  1750                  0.0
# 1      Afghanistan   AF           93  1751                  0.0
# 2      Afghanistan   AF           93  1752                  0.0
# 3      Afghanistan   AF           93  1753                  0.0
# 4      Afghanistan   AF           93  1754                  0.0
# ...            ...  ...          ...   ...                  ...
# 59615     Zimbabwe   ZW          263  2016          736467042.0
# 59616     Zimbabwe   ZW          263  2017          746048675.0
# 59617     Zimbabwe   ZW          263  2018          757903042.0
# 59618     Zimbabwe   ZW          263  2019          768852126.0
# 59619     Zimbabwe   ZW          263  2020          779383468.0
#
#        Population(2022)      Area % of World Density(km2)
# 0            41128771.0  652230.0      0.40%       63/km²
# 1            41128771.0  652230.0      0.40%       63/km²
# ...

# %%
#Información de los datos
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59620 entries, 0 to 59619
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              59620 non-null  object
#  1   Code                 57452 non-null  object
#  2   Calling Code         56097 non-null  object
#  3   Year                 59620 non-null  int64
#  4   CO2 emission (Tons)  59620 non-null  float64
#  5   Population(2022)     53116 non-null  float64
#  6   Area                 55284 non-null  float64
#  7   % of World           55284 non-null  object
#  8   Density(km2)         53116 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 4.1+ MB

# %% [markdown]
# Como se observa en el cuadro de infromación, el porcentaje del mundo y la densidad son de tipo "object", por lo que los convertiremos a tipo float.

# %%
df["% of World"] = df["% of World"].astype(float)

# %%
df["Density(km2)"] = df["Density(km2)"].astype(float)

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59620 entries, 0 to 59619
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              59620 non-null  object
#  1   Code                 57452 non-null  object
#  2   Calling Code         56097 non-null  object
#  3   Year                 59620 non-null  int64
#  4   CO2 emission (Tons)  59620 non-null  float64
#  5   Population(2022)     53116 non-null  float64
#  6   Area                 55284 non-null  float64
#  7   % of World           55284 non-null  float64
#  8   Density(km2)         53116 non-null  float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# ## Visualización de Datos

# %%
emisiones_anuales_co2 = df.groupby("Year").sum()
plt.figure(figsize=(6, 6))
sns.set_style("whitegrid")
plt.plot(yearly_world_emission_df.index, yearly_world_emission_df["CO2 emission (Tons)"])
plt.title("Emisiones Anuales de CO2");
